# %%
import math
import os

import torch
import torch.nn as nn
import torch.nn.functional as F
from random import uniform
from einops.layers.torch import Rearrange
from pytorch_wavelets import DWT, IDWT

import matplotlib.pyplot as plt
from torchvision.transforms import v2
from jdict import jdict

import facer
from facenet_pytorch import MTCNN, InceptionResnetV1

import cv2
from PIL import Image
from insightface.app import FaceAnalysis

import nvdiffrast.torch as dr

import src.shared.util as U 
import src.shared.phong as PH
from src.shared.subdivide import subdivide_trianglemesh

torch.set_printoptions(sci_mode=False, precision=4)

# %%
clean = [
    'luke_skywalker_battlefront_2',
    'catherine_hidden_agenda',
    'becky_hidden_agenda',
    'felicity_hidden_agenda',
    'obi_wan_kenobi_battlefront_2',
    'jefferson_bragg_inpatient',
    'jessica_until_dawn',    
    'dante_dmc',
    'sam_until_dawn',
    'amelia_croft_tomb_raider',
    'cassie_drake_uncharted',
    'jonah_maiava_tomb_raider',
    'lara_croft_child_tomb_raider',    
]
minor = [
    'hero_uncharted',
    'lady_dmc',
    'trish_dmc',
    'v_dmc',
    'nico_dmc',
    'morrison_dmc',
    'vergil_dmc',
    'nero_dmc',
    'mike_until_dawn',
    'richard_croft_tomb_raider',
    'elena_fisher_uncharted',
    'abigaile_ortiz_tomb_raider',
    'claire_resident_evil',
    'hank_detroit',
    'connor_detroit',
    'daniel_detroit',
    'chloe_detroit',
    'angela_civilian_detroit',
    'carl_detroit',
    'enchantress_injustice_2',    
]
good_stls = clean + minor
len(good_stls)
# Out:
# 33

# %%
hp = jdict(    
    device='cuda',    
    renderer_sz=256,    
    camera_position=2.,    
    img_sz=224,
    rndr_sz=512,
    material=0.4,
    color_ratio=0.95,
    color_high=10000,
    direction_ratio=0.9,
    direction_standard=(0.0, 0.0, -1.0),
    eye_x=(-0.2, 0.2),
    eye_y=(-0.2, 0.2),
    eye_z=(2.5, 2.75),
    min_light=0.2,
)

transforms = v2.Compose([
    v2.ToImage(),  # Convert to tensor, only needed if you had a PIL image
    v2.ToDtype(torch.uint8, scale=True),  # optional, most input are already uint8 at this point    
    v2.Resize(size=(224, 224), antialias=True),    
    v2.ToDtype(torch.float32, scale=True),  # Normalize expects float input
    v2.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

device = torch.device('cuda')
glctx = dr.RasterizeGLContext()

flip=[1., 1., -1.]
stl_root = './data/face_stls/'
stls = [f for f in sorted(os.listdir(stl_root))
        if (f.endswith('.stl') and f.replace('.stl', '') in good_stls)]

#dinov1_vitb8 = torch.hub.load('facebookresearch/dino:main', 'dino_vitb8')
#dinov2_vitl14 = torch.hub.load('facebookresearch/dinov2', 'dinov2_vitl14')
#dinov2_vitl14_reg = torch.hub.load('facebookresearch/dinov2', 'dinov2_vitl14_reg')

providers=['CUDAExecutionProvider', 'CPUExecutionProvider']
#app_buffalo_l = FaceAnalysis(name="buffalo_l", providers=providers)
#app_buffalo_l.prepare(ctx_id=0, det_size=(640, 640))

app_antelopev2 = FaceAnalysis(name="antelopev2", providers=['CUDAExecutionProvider', 'CPUExecutionProvider'])
app_antelopev2.prepare(ctx_id=0, det_size=(640, 640))

def face_embedding(app, img_file):    
    img = cv2.imread(img_file)
    faces = app.get(img)
    while len(faces) == 0 and app.det_thresh > 0.35:
        app.det_thresh = app.det_thresh - 0.05
        faces = app.get(img)
    app.det_thresh = 0.5
    if faces:
        return torch.from_numpy(faces[0].normed_embedding)
    return None
# Out:
# Applied providers: ['CUDAExecutionProvider', 'CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}, 'CUDAExecutionProvider': {'prefer_nhwc': '0', 'enable_skip_layer_norm_strict_mode': '0', 'tunable_op_max_tuning_duration_ms': '0', 'use_ep_level_unified_stream': '0', 'tunable_op_enable': '0', 'enable_cuda_graph': '0', 'cudnn_conv_use_max_workspace': '1', 'do_copy_in_default_stream': '1', 'cudnn_conv_algo_search': 'EXHAUSTIVE', 'gpu_external_empty_cache': '0', 'gpu_external_free': '0', 'tunable_op_tuning_enable': '0', 'cudnn_conv1d_pad_to_nc1d': '0', 'gpu_external_alloc': '0', 'arena_extend_strategy': 'kNextPowerOfTwo', 'has_user_compute_stream': '0', 'gpu_mem_limit': '18446744073709551615', 'device_id': '0'}}
# find model: /home/bobi/.insightface/models/antelopev2/1k3d68.onnx landmark_3d_68 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['CUDAExecutionProvider', 'CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}, 'CUDAExecutionProvider': {'prefer_nhwc': '0', 'enable_skip_layer_norm_strict_mode': '0', 'tunable_op_max_tuning_duration_ms': '0', 'use_ep_level_unified_stream': '0', 'tunable_op_enable': '0', 'enable_cuda_graph': '0', 'cudnn_conv_use_max_workspace': '1', 'do_copy_in_default_stream': '1', 'cudnn_conv_algo_search': 'EXHAUSTIVE', 'gpu_external_empty_cache': '0', 'gpu_external_free': '0', 'tunable_op_tuning_enable': '0', 'cudnn_conv1d_pad_to_nc1d': '0', 'gpu_external_alloc': '0', 'arena_extend_strategy': 'kNextPowerOfTwo', 'has_user_compute_stream': '0', 'gpu_mem_limit': '18446744073709551615', 'device_id': '0'}}
# find model: /home/bobi/.insightface/models/antelopev2/2d106det.onnx landmark_2d_106 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['CUDAExecutionProvider', 'CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}, 'CUDAExecutionProvider': {'prefer_nhwc': '0', 'enable_skip_layer_norm_strict_mode': '0', 'tunable_op_max_tuning_duration_ms': '0', 'use_ep_level_unified_stream': '0', 'tunable_op_enable': '0', 'enable_cuda_graph': '0', 'cudnn_conv_use_max_workspace': '1', 'do_copy_in_default_stream': '1', 'cudnn_conv_algo_search': 'EXHAUSTIVE', 'gpu_external_empty_cache': '0', 'gpu_external_free': '0', 'tunable_op_tuning_enable': '0', 'cudnn_conv1d_pad_to_nc1d': '0', 'gpu_external_alloc': '0', 'arena_extend_strategy': 'kNextPowerOfTwo', 'has_user_compute_stream': '0', 'gpu_mem_limit': '18446744073709551615', 'device_id': '0'}}
# find model: /home/bobi/.insightface/models/antelopev2/genderage.onnx genderage ['None', 3, 96, 96] 0.0 1.0
# Applied providers: ['CUDAExecutionProvider', 'CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}, 'CUDAExecutionProvider': {'prefer_nhwc': '0', 'enable_skip_layer_norm_strict_mode': '0', 'tunable_op_max_tuning_duration_ms': '0', 'use_ep_level_unified_stream': '0', 'tunable_op_enable': '0', 'enable_cuda_graph': '0', 'cudnn_conv_use_max_workspace': '1', 'do_copy_in_default_stream': '1', 'cudnn_conv_algo_search': 'EXHAUSTIVE', 'gpu_external_empty_cache': '0', 'gpu_external_free': '0', 'tunable_op_tuning_enable': '0', 'cudnn_conv1d_pad_to_nc1d': '0', 'gpu_external_alloc': '0', 'arena_extend_strategy': 'kNextPowerOfTwo', 'has_user_compute_stream': '0', 'gpu_mem_limit': '18446744073709551615', 'device_id': '0'}}
# find model: /home/bobi/.insightface/models/antelopev2/glintr100.onnx recognition ['None', 3, 112, 112] 127.5 127.5
# Applied providers: ['CUDAExecutionProvider', 'CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}, 'CUDAExecutionProvider': {'prefer_nhwc': '0', 'enable_skip_layer_norm_strict_mode': '0', 'tunable_op_max_tuning_duration_ms': '0', 'use_ep_level_unified_stream': '0', 'tunable_op_enable': '0', 'enable_cuda_graph': '0', 'cudnn_conv_use_max_workspace': '1', 'do_copy_in_default_stream': '1', 'cudnn_conv_algo_search': 'EXHAUSTIVE', 'gpu_external_empty_cache': '0', 'gpu_external_free': '0', 'tunable_op_tuning_enable': '0', 'cudnn_conv1d_pad_to_nc1d': '0', 'gpu_external_alloc': '0', 'arena_extend_strategy': 'kNextPowerOfTwo', 'has_user_compute_stream': '0', 'gpu_mem_limit': '18446744073709551615', 'device_id': '0'}}
# find model: /home/bobi/.insightface/models/antelopev2/scrfd_10g_bnkps.onnx detection [1, 3, '?', '?'] 127.5 128.0
# set det-size: (640, 640)

# %%
flip=[1., 1., -1.]
rs = 0.1
n_samples = 100
n_views = 5

face_emb_dir = './data/face_emb_hq/'
tmp_img_file = './render_img.jpg'

image_flip = v2.RandomHorizontalFlip(1)#(render_img)

for i, file in enumerate(stls):
    # if i < 133:
    #     continue
    print(i, file)
    #if i < 
    # if file.replace('.stl', f'_{0}.pth') in os.listdir(face_emb_dir):
    #     continue
    v, f = U.load_mesh(stl_root + file, flip=flip, batch=True)
    while v.size(1) < 3_000:   
        print(v.shape)
        v, f = subdivide_trianglemesh(v.cpu(), f.long(), 1)    
    
    v, faces = v.cuda(), f.int().cuda()
    material = torch.zeros_like(v) + hp.material
    i = 0
    while i < n_samples:        
        scale = torch.Tensor([uniform(1-rs, 1+rs) for _ in range(3)])
        vertices = v * scale.cuda()
        vertices = vertices / vertices.abs().max()
        j, embeddings = 0, []
        while j < n_views:
            render = PH.render_diffuse(glctx, vertices, faces, material, hp)
            render = render.clamp(0, 1)        
            
            render_img = v2.ToPILImage()(render[0].permute(2, 0, 1)) 
            # flipped = bool(randint(0, 1))
            # if flipped:
            #     render_img = image_flip(render_img)
                
            tmp_img_file = face_emb_dir + file.replace('.stl', f'_{i}.jpg')
            render_img.save(tmp_img_file)
    
            # buffalo = face_embedding(app_buffalo_l, tmp_img_file)
            antelope = face_embedding(app_antelopev2, tmp_img_file)
            if antelope is not None:
                embeddings.append(antelope.detach().cpu())  
                j += 1
        torch.save({
            'scale': scale.cpu(),
            #'buffalo': buffalo.detach().cpu(),
            'antelope': embeddings,                    
            'file': file.replace('.stl', ''),
            #'flipped': flipped,
        }, face_emb_dir + file.replace('.stl', f'_{i}.pth'))            
        i += 1
        print(i, file)
# Out:
# 0 abigaile_ortiz_tomb_raider.stl
# 1 abigaile_ortiz_tomb_raider.stl
# 2 abigaile_ortiz_tomb_raider.stl
# 3 abigaile_ortiz_tomb_raider.stl
# 4 abigaile_ortiz_tomb_raider.stl
# 5 abigaile_ortiz_tomb_raider.stl
# 6 abigaile_ortiz_tomb_raider.stl
# 7 abigaile_ortiz_tomb_raider.stl
# 8 abigaile_ortiz_tomb_raider.stl
# 9 abigaile_ortiz_tomb_raider.stl
# 10 abigaile_ortiz_tomb_raider.stl
# 11 abigaile_ortiz_tomb_raider.stl
# 12 abigaile_ortiz_tomb_raider.stl
# 13 abigaile_ortiz_tomb_raider.stl
# 92 carl_detroit.stl
# 93 carl_detroit.stl
# 94 carl_detroit.stl
# 95 carl_detroit.stl
# 96 carl_detroit.stl
# 97 carl_detroit.stl
# 98 carl_detroit.stl
# 99 carl_detroit.stl
# 100 carl_detroit.stl
# 5 cassie_drake_uncharted.stl
# 1 cassie_drake_uncharted.stl
# 2 cassie_drake_uncharted.stl
# 3 cassie_drake_uncharted.stl
# 4 cassie_drake_uncharted.stl
# 5 cassie_drake_uncharted.stl
# 6 cassie_drake_uncharted.stl
# 7 cassie_drake_uncharted.stl
# 8 cassie_drake_uncharted.stl
# 9 cassie_drake_uncharted.stl
# 10 cassie_drake_uncharted.stl
# 11 cassie_drake_uncharted.stl
# 12 cassie_drake_uncharted.stl
# 13 cassie_drake_uncharted.stl
# 14 cassie_drake_uncharted.stl
# 15 cassie_drake_uncharted.stl
# 16 cassie_drake_uncharted.stl
# 17 cassie_drake_uncharted.stl
# 18 cassie_drake_uncharted.stl
# 19 cassie_drake_uncharted.stl
# 20 cassie_drake_uncharted.stl
# 21 cassie_drake_uncharted.stl
# 22 cassie_drake_uncharted.stl
# 23 cassie_drake_uncharted.stl
# 24 cassie_drake_uncharted.stl
# 25 cassie_drake_uncharted.stl
# 26 cassie_drake_uncharted.stl
# 27 cassie_drake_uncharted.stl
# 28 cassie_drake_uncharted.stl
# 29 cassie_drake_uncharted.stl
# 30 cassie_drake_uncharted.stl
# 31 cassie_drake_uncharted.stl
# 32 cassie_drake_uncharted.stl
# 33 cassie_drake_uncharted.stl
# 34 cassie_drake_uncharted.stl
# 35 cassie_drake_uncharted.stl
# 36 cassie_drake_uncharted.stl
# 37 cassie_drake_uncharted.stl
# 38 cassie_drake_uncharted.stl
# 39 cassie_drake_uncharted.stl
# 40 cassie_drake_uncharted.stl
# 41 cassie_drake_uncharted.stl
# 42 cassie_drake_uncharted.stl
# 43 cassie_drake_uncharted.stl
# 44 cassie_drake_uncharted.stl
# 45 cassie_drake_uncharted.stl
# 46 cassie_drake_uncharted.stl
# 47 cassie_drake_uncharted.stl
# 48 cassie_drake_uncharted.stl
# 49 cassie_drake_uncharted.stl
# 50 cassie_drake_uncharted.stl
# 51 cassie_drake_uncharted.stl
# 52 cassie_drake_uncharted.stl
# 53 cassie_drake_uncharted.stl
# 54 cassie_drake_uncharted.stl
# 55 cassie_drake_uncharted.stl
# 56 cassie_drake_uncharted.stl
# 57 cassie_drake_uncharted.stl
# 58 cassie_drake_uncharted.stl
# 59 cassie_drake_uncharted.stl
# 60 cassie_drake_uncharted.stl
# 61 cassie_drake_uncharted.stl
# 62 cassie_drake_uncharted.stl
# 63 cassie_drake_uncharted.stl
# 64 cassie_drake_uncharted.stl
# 65 cassie_drake_uncharted.stl
# 66 cassie_drake_uncharted.stl
# 67 cassie_drake_uncharted.stl
# 68 cassie_drake_uncharted.stl
# 69 cassie_drake_uncharted.stl
# 70 cassie_drake_uncharted.stl
# 71 cassie_drake_uncharted.stl
# 72 cassie_drake_uncharted.stl
# 73 cassie_drake_uncharted.stl
# 74 cassie_drake_uncharted.stl
# 75 cassie_drake_uncharted.stl
# 76 cassie_drake_uncharted.stl
# 77 cassie_drake_uncharted.stl
# 78 cassie_drake_uncharted.stl
# 79 cassie_drake_uncharted.stl
# 80 cassie_drake_uncharted.stl
# 81 cassie_drake_uncharted.stl
# 82 cassie_drake_uncharted.stl
# 83 cassie_drake_uncharted.stl
# 84 cassie_drake_uncharted.stl
# 85 cassie_drake_uncharted.stl
# 86 cassie_drake_uncharted.stl
# 87 cassie_drake_uncharted.stl
# 88 cassie_drake_uncharted.stl
# 89 cassie_drake_uncharted.stl
# 90 cassie_drake_uncharted.stl
# 91 cassie_drake_uncharted.stl
# 92 cassie_drake_uncharted.stl
# 93 cassie_drake_uncharted.stl
# 94 cassie_drake_uncharted.stl
# 95 cassie_drake_uncharted.stl
# 96 cassie_drake_uncharted.stl
# 97 cassie_drake_uncharted.stl
# 98 cassie_drake_uncharted.stl
# 99 cassie_drake_uncharted.stl
# 100 cassie_drake_uncharted.stl
# 6 catherine_hidden_agenda.stl
# 1 catherine_hidden_agenda.stl
# 2 catherine_hidden_agenda.stl
# 3 catherine_hidden_agenda.stl
# 4 catherine_hidden_agenda.stl
# 5 catherine_hidden_agenda.stl
# 6 catherine_hidden_agenda.stl
# 7 catherine_hidden_agenda.stl
# 8 catherine_hidden_agenda.stl
# 9 catherine_hidden_agenda.stl
# 10 catherine_hidden_agenda.stl
# 11 catherine_hidden_agenda.stl
# 12 catherine_hidden_agenda.stl
# 13 catherine_hidden_agenda.stl
# 14 catherine_hidden_agenda.stl
# 15 catherine_hidden_agenda.stl
# 16 catherine_hidden_agenda.stl
# 17 catherine_hidden_agenda.stl
# 18 catherine_hidden_agenda.stl
# 19 catherine_hidden_agenda.stl
# 20 catherine_hidden_agenda.stl
# 21 catherine_hidden_agenda.stl
# 22 catherine_hidden_agenda.stl
# 23 catherine_hidden_agenda.stl
# 24 catherine_hidden_agenda.stl
# 25 catherine_hidden_agenda.stl
# 26 catherine_hidden_agenda.stl
# 27 catherine_hidden_agenda.stl
# 28 catherine_hidden_agenda.stl
# 29 catherine_hidden_agenda.stl
# 30 catherine_hidden_agenda.stl
# 31 catherine_hidden_agenda.stl
# 32 catherine_hidden_agenda.stl
# 33 catherine_hidden_agenda.stl
# 34 catherine_hidden_agenda.stl
# 35 catherine_hidden_agenda.stl
# 36 catherine_hidden_agenda.stl
# 37 catherine_hidden_agenda.stl
# 38 catherine_hidden_agenda.stl
# 39 catherine_hidden_agenda.stl
# 40 catherine_hidden_agenda.stl
# 41 catherine_hidden_agenda.stl
# 42 catherine_hidden_agenda.stl
# 43 catherine_hidden_agenda.stl
# 44 catherine_hidden_agenda.stl
# 45 catherine_hidden_agenda.stl
# 46 catherine_hidden_agenda.stl
# 47 catherine_hidden_agenda.stl
# 48 catherine_hidden_agenda.stl
# 49 catherine_hidden_agenda.stl
# 50 catherine_hidden_agenda.stl
# 51 catherine_hidden_agenda.stl
# 52 catherine_hidden_agenda.stl
# 53 catherine_hidden_agenda.stl
# 54 catherine_hidden_agenda.stl
# 55 catherine_hidden_agenda.stl
# 56 catherine_hidden_agenda.stl
# 57 catherine_hidden_agenda.stl
# 58 catherine_hidden_agenda.stl
# 59 catherine_hidden_agenda.stl
# 60 catherine_hidden_agenda.stl
# 61 catherine_hidden_agenda.stl
# 62 catherine_hidden_agenda.stl
# 63 catherine_hidden_agenda.stl
# 64 catherine_hidden_agenda.stl
# 65 catherine_hidden_agenda.stl
# 66 catherine_hidden_agenda.stl
# 67 catherine_hidden_agenda.stl
# 68 catherine_hidden_agenda.stl
# 69 catherine_hidden_agenda.stl
# 70 catherine_hidden_agenda.stl
# 71 catherine_hidden_agenda.stl
# 72 catherine_hidden_agenda.stl
# 73 catherine_hidden_agenda.stl
# 74 catherine_hidden_agenda.stl
# 75 catherine_hidden_agenda.stl
# 76 catherine_hidden_agenda.stl
# 77 catherine_hidden_agenda.stl
# 78 catherine_hidden_agenda.stl
# 79 catherine_hidden_agenda.stl
# 80 catherine_hidden_agenda.stl
# 81 catherine_hidden_agenda.stl
# 82 catherine_hidden_agenda.stl
# 83 catherine_hidden_agenda.stl
# 84 catherine_hidden_agenda.stl
# 85 catherine_hidden_agenda.stl
# 86 catherine_hidden_agenda.stl
# 87 catherine_hidden_agenda.stl
# 88 catherine_hidden_agenda.stl
# 89 catherine_hidden_agenda.stl
# 90 catherine_hidden_agenda.stl
# 91 catherine_hidden_agenda.stl
# 92 catherine_hidden_agenda.stl
# 93 catherine_hidden_agenda.stl
# 94 catherine_hidden_agenda.stl
# 95 catherine_hidden_agenda.stl
# 96 catherine_hidden_agenda.stl
# 97 catherine_hidden_agenda.stl
# 98 catherine_hidden_agenda.stl
# 99 catherine_hidden_agenda.stl
# 100 catherine_hidden_agenda.stl
# 7 chloe_detroit.stl
# 1 chloe_detroit.stl
# 2 chloe_detroit.stl
# 3 chloe_detroit.stl
# 4 chloe_detroit.stl
# 5 chloe_detroit.stl
# 6 chloe_detroit.stl
# 7 chloe_detroit.stl
# 8 chloe_detroit.stl
# 9 chloe_detroit.stl
# 10 chloe_detroit.stl
# 11 chloe_detroit.stl
# 12 chloe_detroit.stl
# 13 chloe_detroit.stl
# 14 chloe_detroit.stl
# 15 chloe_detroit.stl
# 16 chloe_detroit.stl
# 17 chloe_detroit.stl
# 18 chloe_detroit.stl
# 19 chloe_detroit.stl
# 20 chloe_detroit.stl
# 21 chloe_detroit.stl
# 22 chloe_detroit.stl
# 23 chloe_detroit.stl
# 24 chloe_detroit.stl
# 25 chloe_detroit.stl
# 26 chloe_detroit.stl
# 27 chloe_detroit.stl
# 28 chloe_detroit.stl
# 29 chloe_detroit.stl
# 30 chloe_detroit.stl
# 31 chloe_detroit.stl
# 32 chloe_detroit.stl
# 33 chloe_detroit.stl
# 34 chloe_detroit.stl
# 35 chloe_detroit.stl
# 36 chloe_detroit.stl
# 37 chloe_detroit.stl
# 38 chloe_detroit.stl
# 39 chloe_detroit.stl
# 38 claire_resident_evil.stl
# 39 claire_resident_evil.stl
# 40 claire_resident_evil.stl
# 41 claire_resident_evil.stl
# 42 claire_resident_evil.stl
# 43 claire_resident_evil.stl
# 44 claire_resident_evil.stl
# 45 claire_resident_evil.stl
# 46 claire_resident_evil.stl
# 47 claire_resident_evil.stl
# 48 claire_resident_evil.stl
# 49 claire_resident_evil.stl
# 50 claire_resident_evil.stl
# 51 claire_resident_evil.stl
# 52 claire_resident_evil.stl
# 53 claire_resident_evil.stl
# 54 claire_resident_evil.stl
# 55 claire_resident_evil.stl
# 56 claire_resident_evil.stl
# 57 claire_resident_evil.stl
# 58 claire_resident_evil.stl
# 59 claire_resident_evil.stl
# 60 claire_resident_evil.stl
# 61 claire_resident_evil.stl
# 62 claire_resident_evil.stl
# 63 claire_resident_evil.stl
# 64 claire_resident_evil.stl
# 65 claire_resident_evil.stl
# 66 claire_resident_evil.stl
# 67 claire_resident_evil.stl
# 68 claire_resident_evil.stl
# 69 claire_resident_evil.stl
# 70 claire_resident_evil.stl
# 71 claire_resident_evil.stl
# 72 claire_resident_evil.stl
# 73 claire_resident_evil.stl
# 74 claire_resident_evil.stl
# 75 claire_resident_evil.stl
# 76 claire_resident_evil.stl
# 77 claire_resident_evil.stl
# 78 claire_resident_evil.stl
# 79 claire_resident_evil.stl
# 80 claire_resident_evil.stl
# 81 claire_resident_evil.stl
# 82 claire_resident_evil.stl
# 83 claire_resident_evil.stl
# 84 claire_resident_evil.stl
# 85 claire_resident_evil.stl
# 86 claire_resident_evil.stl
# 87 claire_resident_evil.stl
# 88 claire_resident_evil.stl
# 89 claire_resident_evil.stl
# 90 claire_resident_evil.stl
# 91 claire_resident_evil.stl
# 92 claire_resident_evil.stl
# 93 claire_resident_evil.stl
# 94 claire_resident_evil.stl
# 95 claire_resident_evil.stl
# 96 claire_resident_evil.stl
# 97 claire_resident_evil.stl
# 98 claire_resident_evil.stl
# 99 claire_resident_evil.stl
# 100 claire_resident_evil.stl
# 9 connor_detroit.stl
# 1 connor_detroit.stl
# 2 connor_detroit.stl
# 3 connor_detroit.stl
# 4 connor_detroit.stl
# 5 connor_detroit.stl
# 6 connor_detroit.stl
# 7 connor_detroit.stl
# 8 connor_detroit.stl
# 9 connor_detroit.stl
# 10 connor_detroit.stl
# 11 connor_detroit.stl
# 12 connor_detroit.stl
# 13 connor_detroit.stl
# 14 connor_detroit.stl
# 15 connor_detroit.stl
# 16 connor_detroit.stl
# 17 connor_detroit.stl
# 18 connor_detroit.stl
# 19 connor_detroit.stl
# 20 connor_detroit.stl
# 21 connor_detroit.stl
# 22 connor_detroit.stl
# 23 connor_detroit.stl
# 24 connor_detroit.stl
# 25 connor_detroit.stl
# 26 connor_detroit.stl
# 27 connor_detroit.stl
# 28 connor_detroit.stl
# 29 connor_detroit.stl
# 30 connor_detroit.stl
# 31 connor_detroit.stl
# 32 connor_detroit.stl
# 33 connor_detroit.stl
# 34 connor_detroit.stl
# 35 connor_detroit.stl
# 36 connor_detroit.stl
# 37 connor_detroit.stl
# 38 connor_detroit.stl
# 39 connor_detroit.stl
# 40 connor_detroit.stl
# 41 connor_detroit.stl
# 42 connor_detroit.stl
# 43 connor_detroit.stl
# 44 connor_detroit.stl
# 45 connor_detroit.stl
# 46 connor_detroit.stl
# 47 connor_detroit.stl
# 48 connor_detroit.stl
# 49 connor_detroit.stl
# 50 connor_detroit.stl
# 51 connor_detroit.stl
# 52 connor_detroit.stl
# 53 connor_detroit.stl
# 54 connor_detroit.stl
# 55 connor_detroit.stl
# 56 connor_detroit.stl
# 57 connor_detroit.stl
# 58 connor_detroit.stl
# 59 connor_detroit.stl
# 60 connor_detroit.stl
# 61 connor_detroit.stl
# 62 connor_detroit.stl
# 63 connor_detroit.stl
# 64 connor_detroit.stl
# 65 connor_detroit.stl
# 66 connor_detroit.stl
# 67 connor_detroit.stl
# 68 connor_detroit.stl
# 69 connor_detroit.stl
# 70 connor_detroit.stl
# 71 connor_detroit.stl
# 72 connor_detroit.stl
# 73 connor_detroit.stl
# 74 connor_detroit.stl
# 75 connor_detroit.stl
# 76 connor_detroit.stl
# 77 connor_detroit.stl
# 78 connor_detroit.stl
# 79 connor_detroit.stl
# 80 connor_detroit.stl
# 81 connor_detroit.stl
# 82 connor_detroit.stl
# 83 connor_detroit.stl
# 84 connor_detroit.stl
# 85 connor_detroit.stl
# 86 connor_detroit.stl
# 87 connor_detroit.stl
# 88 connor_detroit.stl
# 89 connor_detroit.stl
# 90 connor_detroit.stl
# 91 connor_detroit.stl
# 92 connor_detroit.stl
# 93 connor_detroit.stl
# 94 connor_detroit.stl
# 95 connor_detroit.stl
# 96 connor_detroit.stl
# 97 connor_detroit.stl
# 98 connor_detroit.stl
# 99 connor_detroit.stl
# 100 connor_detroit.stl
# 10 daniel_detroit.stl
# 1 daniel_detroit.stl
# 2 daniel_detroit.stl
# 3 daniel_detroit.stl
# 4 daniel_detroit.stl
# 5 daniel_detroit.stl
# 6 daniel_detroit.stl
# 7 daniel_detroit.stl
# 8 daniel_detroit.stl
# 9 daniel_detroit.stl
# 10 daniel_detroit.stl
# 11 daniel_detroit.stl
# 12 daniel_detroit.stl
# 13 daniel_detroit.stl
# 14 daniel_detroit.stl
# 15 daniel_detroit.stl
# 16 daniel_detroit.stl
# 17 daniel_detroit.stl
# 18 daniel_detroit.stl
# 19 daniel_detroit.stl
# 20 daniel_detroit.stl
# 21 daniel_detroit.stl
# 22 daniel_detroit.stl
# 23 daniel_detroit.stl
# 24 daniel_detroit.stl
# 25 daniel_detroit.stl
# 26 daniel_detroit.stl
# 27 daniel_detroit.stl
# 28 daniel_detroit.stl
# 29 daniel_detroit.stl
# 30 daniel_detroit.stl
# 31 daniel_detroit.stl
# 32 daniel_detroit.stl
# 33 daniel_detroit.stl
# 34 daniel_detroit.stl
# 35 daniel_detroit.stl
# 36 daniel_detroit.stl
# 37 daniel_detroit.stl
# 38 daniel_detroit.stl
# 39 daniel_detroit.stl
# 40 daniel_detroit.stl
# 41 daniel_detroit.stl
# 42 daniel_detroit.stl
# 43 daniel_detroit.stl
# 44 daniel_detroit.stl
# 45 daniel_detroit.stl
# 46 daniel_detroit.stl
# 47 daniel_detroit.stl
# 48 daniel_detroit.stl
# 49 daniel_detroit.stl
# 50 daniel_detroit.stl
# 51 daniel_detroit.stl
# 52 daniel_detroit.stl
# 53 daniel_detroit.stl
# 54 daniel_detroit.stl
# 55 daniel_detroit.stl
# 56 daniel_detroit.stl
# 57 daniel_detroit.stl
# 58 daniel_detroit.stl
# 59 daniel_detroit.stl
# 60 daniel_detroit.stl
# 61 daniel_detroit.stl
# 62 daniel_detroit.stl
# 63 daniel_detroit.stl
# 64 daniel_detroit.stl
# 65 daniel_detroit.stl
# 66 daniel_detroit.stl
# 67 daniel_detroit.stl
# 68 daniel_detroit.stl
# 69 daniel_detroit.stl
# 70 daniel_detroit.stl
# 71 daniel_detroit.stl
# 72 daniel_detroit.stl
# 73 daniel_detroit.stl
# 74 daniel_detroit.stl
# 75 daniel_detroit.stl
# 76 daniel_detroit.stl
# 77 daniel_detroit.stl
# 78 daniel_detroit.stl
# 79 daniel_detroit.stl
# 80 daniel_detroit.stl
# 81 daniel_detroit.stl
# 82 daniel_detroit.stl
# 83 daniel_detroit.stl
# 84 daniel_detroit.stl
# 85 daniel_detroit.stl
# 86 daniel_detroit.stl
# 87 daniel_detroit.stl
# 88 daniel_detroit.stl
# 89 daniel_detroit.stl
# 90 daniel_detroit.stl
# 91 daniel_detroit.stl
# 92 daniel_detroit.stl
# 93 daniel_detroit.stl
# 94 daniel_detroit.stl
# 95 daniel_detroit.stl
# 96 daniel_detroit.stl
# 97 daniel_detroit.stl
# 98 daniel_detroit.stl
# 99 daniel_detroit.stl
# 100 daniel_detroit.stl
# 11 dante_dmc.stl
# 1 dante_dmc.stl
# 2 dante_dmc.stl
# 3 dante_dmc.stl
# 4 dante_dmc.stl
# 5 dante_dmc.stl
# 6 dante_dmc.stl
# 7 dante_dmc.stl
# 8 dante_dmc.stl
# 9 dante_dmc.stl
# 10 dante_dmc.stl
# 11 dante_dmc.stl
# 12 dante_dmc.stl
# 13 dante_dmc.stl
# 14 dante_dmc.stl
# 15 dante_dmc.stl
# 16 dante_dmc.stl
# 17 dante_dmc.stl
# 18 dante_dmc.stl
# 19 dante_dmc.stl
# 20 dante_dmc.stl
# 21 dante_dmc.stl
# 22 dante_dmc.stl
# 23 dante_dmc.stl
# 24 dante_dmc.stl
# 25 dante_dmc.stl
# 26 dante_dmc.stl
# 27 dante_dmc.stl
# 28 dante_dmc.stl
# 29 dante_dmc.stl
# 30 dante_dmc.stl
# 31 dante_dmc.stl
# 32 dante_dmc.stl
# 33 dante_dmc.stl
# 34 dante_dmc.stl
# 35 dante_dmc.stl
# 36 dante_dmc.stl
# 37 dante_dmc.stl
# 38 dante_dmc.stl
# 39 dante_dmc.stl
# 40 dante_dmc.stl
# 41 dante_dmc.stl
# 42 dante_dmc.stl
# 43 dante_dmc.stl
# 44 dante_dmc.stl
# 45 dante_dmc.stl
# 46 dante_dmc.stl
# 47 dante_dmc.stl
# 48 dante_dmc.stl
# 49 dante_dmc.stl
# 50 dante_dmc.stl
# 51 dante_dmc.stl
# 52 dante_dmc.stl
# 53 dante_dmc.stl
# 54 dante_dmc.stl
# 55 dante_dmc.stl
# 56 dante_dmc.stl
# 57 dante_dmc.stl
# 58 dante_dmc.stl
# 59 dante_dmc.stl
# 60 dante_dmc.stl
# 61 dante_dmc.stl
# 62 dante_dmc.stl
# 63 dante_dmc.stl
# 64 dante_dmc.stl
# 65 dante_dmc.stl
# 66 dante_dmc.stl
# 67 dante_dmc.stl
# 68 dante_dmc.stl
# 69 dante_dmc.stl
# 70 dante_dmc.stl
# 71 dante_dmc.stl
# 72 dante_dmc.stl
# 73 dante_dmc.stl
# 74 dante_dmc.stl
# 75 dante_dmc.stl
# 76 dante_dmc.stl
# 77 dante_dmc.stl
# 78 dante_dmc.stl
# 79 dante_dmc.stl
# 80 dante_dmc.stl
# 81 dante_dmc.stl
# 82 dante_dmc.stl
# 83 dante_dmc.stl
# 84 dante_dmc.stl
# 85 dante_dmc.stl
# 86 dante_dmc.stl
# 87 dante_dmc.stl
# 88 dante_dmc.stl
# 89 dante_dmc.stl
# 90 dante_dmc.stl
# 91 dante_dmc.stl
# 92 dante_dmc.stl
# 93 dante_dmc.stl
# 94 dante_dmc.stl
# 95 dante_dmc.stl
# 96 dante_dmc.stl
# 97 dante_dmc.stl
# 98 dante_dmc.stl
# 99 dante_dmc.stl
# 100 dante_dmc.stl
# 12 elena_fisher_uncharted.stl
# 1 elena_fisher_uncharted.stl
# 2 elena_fisher_uncharted.stl
# 3 elena_fisher_uncharted.stl
# 4 elena_fisher_uncharted.stl
# 5 elena_fisher_uncharted.stl
# 6 elena_fisher_uncharted.stl
# 7 elena_fisher_uncharted.stl
# 8 elena_fisher_uncharted.stl
# 9 elena_fisher_uncharted.stl
# 10 elena_fisher_uncharted.stl
# 11 elena_fisher_uncharted.stl
# 12 elena_fisher_uncharted.stl
# 13 elena_fisher_uncharted.stl
# 14 elena_fisher_uncharted.stl
# 15 elena_fisher_uncharted.stl
# 16 elena_fisher_uncharted.stl
# 17 elena_fisher_uncharted.stl
# 18 elena_fisher_uncharted.stl
# 19 elena_fisher_uncharted.stl
# 20 elena_fisher_uncharted.stl
# 21 elena_fisher_uncharted.stl
# 22 elena_fisher_uncharted.stl
# 23 elena_fisher_uncharted.stl
# 24 elena_fisher_uncharted.stl
# 25 elena_fisher_uncharted.stl
# 26 elena_fisher_uncharted.stl
# 27 elena_fisher_uncharted.stl
# 28 elena_fisher_uncharted.stl
# 29 elena_fisher_uncharted.stl
# 30 elena_fisher_uncharted.stl
# 31 elena_fisher_uncharted.stl
# 32 elena_fisher_uncharted.stl
# 33 elena_fisher_uncharted.stl
# 34 elena_fisher_uncharted.stl
# 35 elena_fisher_uncharted.stl
# 36 elena_fisher_uncharted.stl
# 37 elena_fisher_uncharted.stl
# 38 elena_fisher_uncharted.stl
# 39 elena_fisher_uncharted.stl
# 40 elena_fisher_uncharted.stl
# 41 elena_fisher_uncharted.stl
# 42 elena_fisher_uncharted.stl
# 43 elena_fisher_uncharted.stl
# 44 elena_fisher_uncharted.stl
# 45 elena_fisher_uncharted.stl
# 46 elena_fisher_uncharted.stl
# 47 elena_fisher_uncharted.stl
# 48 elena_fisher_uncharted.stl
# 49 elena_fisher_uncharted.stl
# 50 elena_fisher_uncharted.stl
# 51 elena_fisher_uncharted.stl
# 52 elena_fisher_uncharted.stl
# 53 elena_fisher_uncharted.stl
# 54 elena_fisher_uncharted.stl
# 55 elena_fisher_uncharted.stl
# 56 elena_fisher_uncharted.stl
# 57 elena_fisher_uncharted.stl
# 58 elena_fisher_uncharted.stl
# 59 elena_fisher_uncharted.stl
# 60 elena_fisher_uncharted.stl
# 61 elena_fisher_uncharted.stl
# 62 elena_fisher_uncharted.stl
# 63 elena_fisher_uncharted.stl
# 64 elena_fisher_uncharted.stl
# 65 elena_fisher_uncharted.stl
# 66 elena_fisher_uncharted.stl
# 67 elena_fisher_uncharted.stl
# 68 elena_fisher_uncharted.stl
# 69 elena_fisher_uncharted.stl
# 70 elena_fisher_uncharted.stl
# 71 elena_fisher_uncharted.stl
# 72 elena_fisher_uncharted.stl
# 73 elena_fisher_uncharted.stl
# 74 elena_fisher_uncharted.stl
# 75 elena_fisher_uncharted.stl
# 76 elena_fisher_uncharted.stl
# 77 elena_fisher_uncharted.stl
# 78 elena_fisher_uncharted.stl
# 79 elena_fisher_uncharted.stl
# 80 elena_fisher_uncharted.stl
# 81 elena_fisher_uncharted.stl
# 82 elena_fisher_uncharted.stl
# 83 elena_fisher_uncharted.stl
# 84 elena_fisher_uncharted.stl
# 85 elena_fisher_uncharted.stl
# 86 elena_fisher_uncharted.stl
# 87 elena_fisher_uncharted.stl
# 88 elena_fisher_uncharted.stl
# 89 elena_fisher_uncharted.stl
# 90 elena_fisher_uncharted.stl
# 91 elena_fisher_uncharted.stl
# 92 elena_fisher_uncharted.stl
# 93 elena_fisher_uncharted.stl
# 94 elena_fisher_uncharted.stl
# 95 elena_fisher_uncharted.stl
# 96 elena_fisher_uncharted.stl
# 97 elena_fisher_uncharted.stl
# 98 elena_fisher_uncharted.stl
# 99 elena_fisher_uncharted.stl
# 100 elena_fisher_uncharted.stl
# 13 enchantress_injustice_2.stl
# 1 enchantress_injustice_2.stl
# 2 enchantress_injustice_2.stl
# 3 enchantress_injustice_2.stl
# 4 enchantress_injustice_2.stl
# 5 enchantress_injustice_2.stl
# 6 enchantress_injustice_2.stl
# 7 enchantress_injustice_2.stl
# 8 enchantress_injustice_2.stl
# 9 enchantress_injustice_2.stl
# 10 enchantress_injustice_2.stl
# 11 enchantress_injustice_2.stl
# 12 enchantress_injustice_2.stl
# 13 enchantress_injustice_2.stl
# 14 enchantress_injustice_2.stl
# 15 enchantress_injustice_2.stl
# 16 enchantress_injustice_2.stl
# 17 enchantress_injustice_2.stl
# 2 felicity_hidden_agenda.stl
# 3 felicity_hidden_agenda.stl
# 4 felicity_hidden_agenda.stl
# 5 felicity_hidden_agenda.stl
# 6 felicity_hidden_agenda.stl
# 7 felicity_hidden_agenda.stl
# 8 felicity_hidden_agenda.stl
# 9 felicity_hidden_agenda.stl
# 10 felicity_hidden_agenda.stl
# 11 felicity_hidden_agenda.stl
# 12 felicity_hidden_agenda.stl
# 13 felicity_hidden_agenda.stl
# 14 felicity_hidden_agenda.stl
# 15 felicity_hidden_agenda.stl
# 16 felicity_hidden_agenda.stl
# 17 felicity_hidden_agenda.stl
# 18 felicity_hidden_agenda.stl
# 19 felicity_hidden_agenda.stl
# 20 felicity_hidden_agenda.stl
# 21 felicity_hidden_agenda.stl
# 22 felicity_hidden_agenda.stl
# 23 felicity_hidden_agenda.stl
# 24 felicity_hidden_agenda.stl
# 25 felicity_hidden_agenda.stl
# 26 felicity_hidden_agenda.stl
# 27 felicity_hidden_agenda.stl
# 28 felicity_hidden_agenda.stl
# 29 felicity_hidden_agenda.stl
# 30 felicity_hidden_agenda.stl
# 31 felicity_hidden_agenda.stl
# 32 felicity_hidden_agenda.stl
# 33 felicity_hidden_agenda.stl
# 34 felicity_hidden_agenda.stl
# 35 felicity_hidden_agenda.stl
# 36 felicity_hidden_agenda.stl
# 37 felicity_hidden_agenda.stl
# 38 felicity_hidden_agenda.stl
# 39 felicity_hidden_agenda.stl
# 40 felicity_hidden_agenda.stl
# 41 felicity_hidden_agenda.stl
# 42 felicity_hidden_agenda.stl
# 43 felicity_hidden_agenda.stl
# 44 felicity_hidden_agenda.stl
# 45 felicity_hidden_agenda.stl
# 46 felicity_hidden_agenda.stl
# 47 felicity_hidden_agenda.stl
# 48 felicity_hidden_agenda.stl
# 49 felicity_hidden_agenda.stl
# 50 felicity_hidden_agenda.stl
# 51 felicity_hidden_agenda.stl
# 52 felicity_hidden_agenda.stl
# 53 felicity_hidden_agenda.stl
# 54 felicity_hidden_agenda.stl
# 55 felicity_hidden_agenda.stl
# 56 felicity_hidden_agenda.stl
# 57 felicity_hidden_agenda.stl
# 58 felicity_hidden_agenda.stl
# 59 felicity_hidden_agenda.stl
# 60 felicity_hidden_agenda.stl
# 61 felicity_hidden_agenda.stl
# 62 felicity_hidden_agenda.stl
# 63 felicity_hidden_agenda.stl
# 64 felicity_hidden_agenda.stl
# 65 felicity_hidden_agenda.stl
# 66 felicity_hidden_agenda.stl
# 67 felicity_hidden_agenda.stl
# 68 felicity_hidden_agenda.stl
# 69 felicity_hidden_agenda.stl
# 70 felicity_hidden_agenda.stl
# 71 felicity_hidden_agenda.stl
# 72 felicity_hidden_agenda.stl
# 73 felicity_hidden_agenda.stl
# 74 felicity_hidden_agenda.stl
# 75 felicity_hidden_agenda.stl
# 76 felicity_hidden_agenda.stl
# 77 felicity_hidden_agenda.stl
# 78 felicity_hidden_agenda.stl
# 79 felicity_hidden_agenda.stl
# 80 felicity_hidden_agenda.stl
# 81 felicity_hidden_agenda.stl
# 82 felicity_hidden_agenda.stl
# 83 felicity_hidden_agenda.stl
# 84 felicity_hidden_agenda.stl
# 85 felicity_hidden_agenda.stl
# 86 felicity_hidden_agenda.stl
# 87 felicity_hidden_agenda.stl
# 88 felicity_hidden_agenda.stl
# 89 felicity_hidden_agenda.stl
# 90 felicity_hidden_agenda.stl
# 91 felicity_hidden_agenda.stl
# 92 felicity_hidden_agenda.stl
# 93 felicity_hidden_agenda.stl
# 94 felicity_hidden_agenda.stl
# 95 felicity_hidden_agenda.stl
# 96 felicity_hidden_agenda.stl
# 97 felicity_hidden_agenda.stl
# 98 felicity_hidden_agenda.stl
# 99 felicity_hidden_agenda.stl
# 100 felicity_hidden_agenda.stl
# 15 hank_detroit.stl
# 1 hank_detroit.stl
# 2 hank_detroit.stl
# 3 hank_detroit.stl
# 4 hank_detroit.stl
# 5 hank_detroit.stl
# 6 hank_detroit.stl
# 7 hank_detroit.stl
# 8 hank_detroit.stl
# 9 hank_detroit.stl
# 10 hank_detroit.stl
# 11 hank_detroit.stl
# 12 hank_detroit.stl
# 13 hank_detroit.stl
# 14 hank_detroit.stl
# 15 hank_detroit.stl
# 16 hank_detroit.stl
# 17 hank_detroit.stl
# 18 hank_detroit.stl
# 19 hank_detroit.stl
# 20 hank_detroit.stl
# 21 hank_detroit.stl
# 22 hank_detroit.stl
# 23 hank_detroit.stl
# 24 hank_detroit.stl
# 25 hank_detroit.stl
# 26 hank_detroit.stl
# 27 hank_detroit.stl
# 28 hank_detroit.stl
# 29 hank_detroit.stl
# 30 hank_detroit.stl
# 31 hank_detroit.stl
# 32 hank_detroit.stl
# 33 hank_detroit.stl
# 34 hank_detroit.stl
# 35 hank_detroit.stl
# 36 hank_detroit.stl
# 37 hank_detroit.stl
# 38 hank_detroit.stl
# 39 hank_detroit.stl
# 40 hank_detroit.stl
# 41 hank_detroit.stl
# 42 hank_detroit.stl
# 43 hank_detroit.stl
# 44 hank_detroit.stl
# 45 hank_detroit.stl
# 46 hank_detroit.stl
# 47 hank_detroit.stl
# 48 hank_detroit.stl
# 49 hank_detroit.stl
# 50 hank_detroit.stl
# 51 hank_detroit.stl
# 52 hank_detroit.stl
# 53 hank_detroit.stl
# 54 hank_detroit.stl
# 55 hank_detroit.stl
# 56 hank_detroit.stl
# 57 hank_detroit.stl
# 58 hank_detroit.stl
# 59 hank_detroit.stl
# 60 hank_detroit.stl
# 61 hank_detroit.stl
# 62 hank_detroit.stl
# 63 hank_detroit.stl
# 64 hank_detroit.stl
# 65 hank_detroit.stl
# 66 hank_detroit.stl
# 67 hank_detroit.stl
# 68 hank_detroit.stl
# 69 hank_detroit.stl
# 70 hank_detroit.stl
# 71 hank_detroit.stl
# 72 hank_detroit.stl
# 73 hank_detroit.stl
# 74 hank_detroit.stl
# 75 hank_detroit.stl
# 76 hank_detroit.stl
# 77 hank_detroit.stl
# 78 hank_detroit.stl
# 79 hank_detroit.stl
# 80 hank_detroit.stl
# 81 hank_detroit.stl
# 82 hank_detroit.stl
# 83 hank_detroit.stl
# 84 hank_detroit.stl
# 85 hank_detroit.stl
# 86 hank_detroit.stl
# 87 hank_detroit.stl
# 88 hank_detroit.stl
# 89 hank_detroit.stl
# 90 hank_detroit.stl
# 91 hank_detroit.stl
# 92 hank_detroit.stl
# 93 hank_detroit.stl
# 94 hank_detroit.stl
# 95 hank_detroit.stl
# 96 hank_detroit.stl
# 97 hank_detroit.stl
# 98 hank_detroit.stl
# 99 hank_detroit.stl
# 100 hank_detroit.stl
# 16 hero_uncharted.stl
# 1 hero_uncharted.stl
# 2 hero_uncharted.stl
# 3 hero_uncharted.stl
# 4 hero_uncharted.stl
# 5 hero_uncharted.stl
# 6 hero_uncharted.stl
# 7 hero_uncharted.stl
# 8 hero_uncharted.stl
# 9 hero_uncharted.stl
# 10 hero_uncharted.stl
# 11 hero_uncharted.stl
# 12 hero_uncharted.stl
# 13 hero_uncharted.stl
# 14 hero_uncharted.stl
# 15 hero_uncharted.stl
# 16 hero_uncharted.stl
# 17 hero_uncharted.stl
# 18 hero_uncharted.stl
# 19 hero_uncharted.stl
# 20 hero_uncharted.stl
# 21 hero_uncharted.stl
# 22 hero_uncharted.stl
# 23 hero_uncharted.stl
# 24 hero_uncharted.stl
# 25 hero_uncharted.stl
# 26 hero_uncharted.stl
# 27 hero_uncharted.stl
# 28 hero_uncharted.stl
# 29 hero_uncharted.stl
# 30 hero_uncharted.stl
# 31 hero_uncharted.stl
# 32 hero_uncharted.stl
# 33 hero_uncharted.stl
# 34 hero_uncharted.stl
# 35 hero_uncharted.stl
# 36 hero_uncharted.stl
# 37 hero_uncharted.stl
# 38 hero_uncharted.stl
# 39 hero_uncharted.stl
# 40 hero_uncharted.stl
# 41 hero_uncharted.stl
# 42 hero_uncharted.stl
# 43 hero_uncharted.stl
# 44 hero_uncharted.stl
# 45 hero_uncharted.stl
# 46 hero_uncharted.stl
# 47 hero_uncharted.stl
# 48 hero_uncharted.stl
# 49 hero_uncharted.stl
# 50 hero_uncharted.stl
# 51 hero_uncharted.stl
# 52 hero_uncharted.stl
# 53 hero_uncharted.stl
# 54 hero_uncharted.stl
# 55 hero_uncharted.stl
# 56 hero_uncharted.stl
# 57 hero_uncharted.stl
# 58 hero_uncharted.stl
# 59 hero_uncharted.stl
# 60 hero_uncharted.stl
# 61 hero_uncharted.stl
# 62 hero_uncharted.stl
# 63 hero_uncharted.stl
# 64 hero_uncharted.stl
# 65 hero_uncharted.stl
# 66 hero_uncharted.stl
# 67 hero_uncharted.stl
# 68 hero_uncharted.stl
# 69 hero_uncharted.stl
# 70 hero_uncharted.stl
# 71 hero_uncharted.stl
# 72 hero_uncharted.stl
# 73 hero_uncharted.stl
# 74 hero_uncharted.stl
# 75 hero_uncharted.stl
# 76 hero_uncharted.stl
# 77 hero_uncharted.stl
# 78 hero_uncharted.stl
# 79 hero_uncharted.stl
# 80 hero_uncharted.stl
# 81 hero_uncharted.stl
# 82 hero_uncharted.stl
# 83 hero_uncharted.stl
# 60 jefferson_bragg_inpatient.stl
# 61 jefferson_bragg_inpatient.stl
# 62 jefferson_bragg_inpatient.stl
# 63 jefferson_bragg_inpatient.stl
# 64 jefferson_bragg_inpatient.stl
# 65 jefferson_bragg_inpatient.stl
# 66 jefferson_bragg_inpatient.stl
# 67 jefferson_bragg_inpatient.stl
# 68 jefferson_bragg_inpatient.stl
# 69 jefferson_bragg_inpatient.stl
# 70 jefferson_bragg_inpatient.stl
# 71 jefferson_bragg_inpatient.stl
# 72 jefferson_bragg_inpatient.stl
# 73 jefferson_bragg_inpatient.stl
# 74 jefferson_bragg_inpatient.stl
# 75 jefferson_bragg_inpatient.stl
# 76 jefferson_bragg_inpatient.stl
# 77 jefferson_bragg_inpatient.stl
# 78 jefferson_bragg_inpatient.stl
# 79 jefferson_bragg_inpatient.stl
# 80 jefferson_bragg_inpatient.stl
# 81 jefferson_bragg_inpatient.stl
# 82 jefferson_bragg_inpatient.stl
# 83 jefferson_bragg_inpatient.stl
# 84 jefferson_bragg_inpatient.stl
# 85 jefferson_bragg_inpatient.stl
# 86 jefferson_bragg_inpatient.stl
# 87 jefferson_bragg_inpatient.stl
# ...
# 76 nero_dmc.stl
# 77 nero_dmc.stl
# 78 nero_dmc.stl
# 79 nero_dmc.stl
# 80 nero_dmc.stl
# 81 nero_dmc.stl
# 82 nero_dmc.stl
# 83 nero_dmc.stl
# 84 nero_dmc.stl
# 85 nero_dmc.stl
# 86 nero_dmc.stl
# 87 nero_dmc.stl
# 88 nero_dmc.stl
# 89 nero_dmc.stl
# 90 nero_dmc.stl
# 91 nero_dmc.stl
# 92 nero_dmc.stl
# 93 nero_dmc.stl
# 94 nero_dmc.stl
# 95 nero_dmc.stl
# 96 nero_dmc.stl
# 97 nero_dmc.stl
# 98 nero_dmc.stl
# 99 nero_dmc.stl
# 100 nero_dmc.stl
# 26 nico_dmc.stl
# 1 nico_dmc.stl
# 2 nico_dmc.stl
# 3 nico_dmc.stl
# 4 nico_dmc.stl
# 5 nico_dmc.stl
# 6 nico_dmc.stl
# 7 nico_dmc.stl
# 8 nico_dmc.stl
# 9 nico_dmc.stl
# 10 nico_dmc.stl
# 11 nico_dmc.stl
# 12 nico_dmc.stl
# 13 nico_dmc.stl
# 14 nico_dmc.stl
# 15 nico_dmc.stl
# 16 nico_dmc.stl
# 17 nico_dmc.stl
# 18 nico_dmc.stl
# 19 nico_dmc.stl
# 20 nico_dmc.stl
# 21 nico_dmc.stl
# 22 nico_dmc.stl
# 23 nico_dmc.stl
# 24 nico_dmc.stl
# 25 nico_dmc.stl
# 26 nico_dmc.stl
# 27 nico_dmc.stl
# 28 nico_dmc.stl
# 29 nico_dmc.stl
# 30 nico_dmc.stl
# 31 nico_dmc.stl
# 32 nico_dmc.stl
# 33 nico_dmc.stl
# 34 nico_dmc.stl
# 35 nico_dmc.stl
# 36 nico_dmc.stl
# 37 nico_dmc.stl
# 38 nico_dmc.stl
# 39 nico_dmc.stl
# 40 nico_dmc.stl
# 41 nico_dmc.stl
# 42 nico_dmc.stl
# 43 nico_dmc.stl
# 44 nico_dmc.stl
# 45 nico_dmc.stl
# 46 nico_dmc.stl
# 47 nico_dmc.stl
# 48 nico_dmc.stl
# 49 nico_dmc.stl
# 50 nico_dmc.stl
# 51 nico_dmc.stl
# 52 nico_dmc.stl
# 53 nico_dmc.stl
# 54 nico_dmc.stl
# 55 nico_dmc.stl
# 56 nico_dmc.stl
# 57 nico_dmc.stl
# 58 nico_dmc.stl
# 59 nico_dmc.stl
# 60 nico_dmc.stl
# 61 nico_dmc.stl
# 62 nico_dmc.stl
# 63 nico_dmc.stl
# 64 nico_dmc.stl
# 65 nico_dmc.stl
# 66 nico_dmc.stl
# 67 nico_dmc.stl
# 68 nico_dmc.stl
# 69 nico_dmc.stl
# 70 nico_dmc.stl
# 71 nico_dmc.stl
# 72 nico_dmc.stl
# 73 nico_dmc.stl
# 74 nico_dmc.stl
# 75 nico_dmc.stl
# 76 nico_dmc.stl
# 77 nico_dmc.stl
# 78 nico_dmc.stl
# 79 nico_dmc.stl
# 80 nico_dmc.stl
# 81 nico_dmc.stl
# 82 nico_dmc.stl
# 83 nico_dmc.stl
# 84 nico_dmc.stl
# 85 nico_dmc.stl
# 86 nico_dmc.stl
# 87 nico_dmc.stl
# 88 nico_dmc.stl
# 89 nico_dmc.stl
# 90 nico_dmc.stl
# 91 nico_dmc.stl
# 92 nico_dmc.stl
# 93 nico_dmc.stl
# 94 nico_dmc.stl
# 95 nico_dmc.stl
# 96 nico_dmc.stl
# 97 nico_dmc.stl
# 98 nico_dmc.stl
# 99 nico_dmc.stl
# 100 nico_dmc.stl
# 27 obi_wan_kenobi_battlefront_2.stl
# 1 obi_wan_kenobi_battlefront_2.stl
# 2 obi_wan_kenobi_battlefront_2.stl
# 3 obi_wan_kenobi_battlefront_2.stl
# 4 obi_wan_kenobi_battlefront_2.stl
# 5 obi_wan_kenobi_battlefront_2.stl
# 6 obi_wan_kenobi_battlefront_2.stl
# 7 obi_wan_kenobi_battlefront_2.stl
# 8 obi_wan_kenobi_battlefront_2.stl
# 9 obi_wan_kenobi_battlefront_2.stl
# 10 obi_wan_kenobi_battlefront_2.stl
# 11 obi_wan_kenobi_battlefront_2.stl
# 12 obi_wan_kenobi_battlefront_2.stl
# 13 obi_wan_kenobi_battlefront_2.stl
# 14 obi_wan_kenobi_battlefront_2.stl
# 15 obi_wan_kenobi_battlefront_2.stl
# 16 obi_wan_kenobi_battlefront_2.stl
# 17 obi_wan_kenobi_battlefront_2.stl
# 18 obi_wan_kenobi_battlefront_2.stl
# 19 obi_wan_kenobi_battlefront_2.stl
# 20 obi_wan_kenobi_battlefront_2.stl
# 21 obi_wan_kenobi_battlefront_2.stl
# 22 obi_wan_kenobi_battlefront_2.stl
# 23 obi_wan_kenobi_battlefront_2.stl
# 24 obi_wan_kenobi_battlefront_2.stl
# 25 obi_wan_kenobi_battlefront_2.stl
# 26 obi_wan_kenobi_battlefront_2.stl
# 27 obi_wan_kenobi_battlefront_2.stl
# 60 richard_croft_tomb_raider.stl
# 61 richard_croft_tomb_raider.stl
# 62 richard_croft_tomb_raider.stl
# 63 richard_croft_tomb_raider.stl
# 64 richard_croft_tomb_raider.stl
# 65 richard_croft_tomb_raider.stl
# 66 richard_croft_tomb_raider.stl
# 67 richard_croft_tomb_raider.stl
# 68 richard_croft_tomb_raider.stl
# 69 richard_croft_tomb_raider.stl
# 70 richard_croft_tomb_raider.stl
# 71 richard_croft_tomb_raider.stl
# 72 richard_croft_tomb_raider.stl
# 73 richard_croft_tomb_raider.stl
# 74 richard_croft_tomb_raider.stl
# 75 richard_croft_tomb_raider.stl
# 76 richard_croft_tomb_raider.stl
# 77 richard_croft_tomb_raider.stl
# 78 richard_croft_tomb_raider.stl
# 79 richard_croft_tomb_raider.stl
# 80 richard_croft_tomb_raider.stl
# 81 richard_croft_tomb_raider.stl
# 82 richard_croft_tomb_raider.stl
# 83 richard_croft_tomb_raider.stl
# 84 richard_croft_tomb_raider.stl
# 85 richard_croft_tomb_raider.stl
# 86 richard_croft_tomb_raider.stl
# 87 richard_croft_tomb_raider.stl
# 88 richard_croft_tomb_raider.stl
# 89 richard_croft_tomb_raider.stl
# 90 richard_croft_tomb_raider.stl
# 91 richard_croft_tomb_raider.stl
# 92 richard_croft_tomb_raider.stl
# 93 richard_croft_tomb_raider.stl
# 94 richard_croft_tomb_raider.stl
# 95 richard_croft_tomb_raider.stl
# 96 richard_croft_tomb_raider.stl
# 97 richard_croft_tomb_raider.stl
# 98 richard_croft_tomb_raider.stl
# 99 richard_croft_tomb_raider.stl
# 100 richard_croft_tomb_raider.stl
# 29 sam_until_dawn.stl
# 1 sam_until_dawn.stl
# 2 sam_until_dawn.stl
# 3 sam_until_dawn.stl
# 4 sam_until_dawn.stl
# 5 sam_until_dawn.stl
# 6 sam_until_dawn.stl
# 7 sam_until_dawn.stl
# 8 sam_until_dawn.stl
# 9 sam_until_dawn.stl
# 10 sam_until_dawn.stl
# 11 sam_until_dawn.stl
# 12 sam_until_dawn.stl
# 13 sam_until_dawn.stl
# 14 sam_until_dawn.stl
# 15 sam_until_dawn.stl
# 16 sam_until_dawn.stl
# 17 sam_until_dawn.stl
# 18 sam_until_dawn.stl
# 19 sam_until_dawn.stl
# 20 sam_until_dawn.stl
# 21 sam_until_dawn.stl
# 22 sam_until_dawn.stl
# 23 sam_until_dawn.stl
# 24 sam_until_dawn.stl
# 25 sam_until_dawn.stl
# 26 sam_until_dawn.stl
# 27 sam_until_dawn.stl
# 28 sam_until_dawn.stl
# 29 sam_until_dawn.stl
# 30 sam_until_dawn.stl
# 31 sam_until_dawn.stl
# 32 sam_until_dawn.stl
# 33 sam_until_dawn.stl
# 34 sam_until_dawn.stl
# 35 sam_until_dawn.stl
# 36 sam_until_dawn.stl
# 37 sam_until_dawn.stl
# 38 sam_until_dawn.stl
# 39 sam_until_dawn.stl
# 40 sam_until_dawn.stl
# 41 sam_until_dawn.stl
# 42 sam_until_dawn.stl
# 43 sam_until_dawn.stl
# 44 sam_until_dawn.stl
# 45 sam_until_dawn.stl
# 46 sam_until_dawn.stl
# 47 sam_until_dawn.stl
# 48 sam_until_dawn.stl
# 49 sam_until_dawn.stl
# 50 sam_until_dawn.stl
# 51 sam_until_dawn.stl
# 52 sam_until_dawn.stl
# 53 sam_until_dawn.stl
# 54 sam_until_dawn.stl
# 55 sam_until_dawn.stl
# 56 sam_until_dawn.stl
# 57 sam_until_dawn.stl
# 58 sam_until_dawn.stl
# 59 sam_until_dawn.stl
# 60 sam_until_dawn.stl
# 61 sam_until_dawn.stl
# 62 sam_until_dawn.stl
# 63 sam_until_dawn.stl
# 64 sam_until_dawn.stl
# 65 sam_until_dawn.stl
# 66 sam_until_dawn.stl
# 67 sam_until_dawn.stl
# 68 sam_until_dawn.stl
# 69 sam_until_dawn.stl
# 70 sam_until_dawn.stl
# 71 sam_until_dawn.stl
# 72 sam_until_dawn.stl
# 73 sam_until_dawn.stl
# 74 sam_until_dawn.stl
# 75 sam_until_dawn.stl
# 76 sam_until_dawn.stl
# 77 sam_until_dawn.stl
# 78 sam_until_dawn.stl
# 79 sam_until_dawn.stl
# 80 sam_until_dawn.stl
# 81 sam_until_dawn.stl
# 82 sam_until_dawn.stl
# 83 sam_until_dawn.stl
# 84 sam_until_dawn.stl
# 85 sam_until_dawn.stl
# 86 sam_until_dawn.stl
# 87 sam_until_dawn.stl
# 88 sam_until_dawn.stl
# 89 sam_until_dawn.stl
# 90 sam_until_dawn.stl
# 91 sam_until_dawn.stl
# 92 sam_until_dawn.stl
# 93 sam_until_dawn.stl
# 94 sam_until_dawn.stl
# 95 sam_until_dawn.stl
# 96 sam_until_dawn.stl
# 97 sam_until_dawn.stl
# 98 sam_until_dawn.stl
# 99 sam_until_dawn.stl
# 100 sam_until_dawn.stl
# 30 trish_dmc.stl
# 1 trish_dmc.stl
# 2 trish_dmc.stl
# 3 trish_dmc.stl
# 4 trish_dmc.stl
# 5 trish_dmc.stl
# 6 trish_dmc.stl
# 7 trish_dmc.stl
# 8 trish_dmc.stl
# 9 trish_dmc.stl
# 10 trish_dmc.stl
# 11 trish_dmc.stl
# 12 trish_dmc.stl
# 13 trish_dmc.stl
# 14 trish_dmc.stl
# 15 trish_dmc.stl
# 16 trish_dmc.stl
# 17 trish_dmc.stl
# 18 trish_dmc.stl
# 19 trish_dmc.stl
# 20 trish_dmc.stl
# 21 trish_dmc.stl
# 22 trish_dmc.stl
# 23 trish_dmc.stl
# 24 trish_dmc.stl
# 25 trish_dmc.stl
# 26 trish_dmc.stl
# 27 trish_dmc.stl
# 28 trish_dmc.stl
# 29 trish_dmc.stl
# 30 trish_dmc.stl
# 31 trish_dmc.stl
# 32 trish_dmc.stl
# 33 trish_dmc.stl
# 34 trish_dmc.stl
# 35 trish_dmc.stl
# 36 trish_dmc.stl
# 37 trish_dmc.stl
# 38 trish_dmc.stl
# 39 trish_dmc.stl
# 40 trish_dmc.stl
# 41 trish_dmc.stl
# 42 trish_dmc.stl
# 43 trish_dmc.stl
# 44 trish_dmc.stl
# 45 trish_dmc.stl
# 46 trish_dmc.stl
# 47 trish_dmc.stl
# 48 trish_dmc.stl
# 49 trish_dmc.stl
# 50 trish_dmc.stl
# 51 trish_dmc.stl
# 52 trish_dmc.stl
# 53 trish_dmc.stl
# 54 trish_dmc.stl
# 55 trish_dmc.stl
# 56 trish_dmc.stl
# 57 trish_dmc.stl
# 58 trish_dmc.stl
# 59 trish_dmc.stl
# 60 trish_dmc.stl
# 61 trish_dmc.stl
# 62 trish_dmc.stl
# 63 trish_dmc.stl
# 64 trish_dmc.stl
# 65 trish_dmc.stl
# 66 trish_dmc.stl
# 67 trish_dmc.stl
# 68 trish_dmc.stl
# 69 trish_dmc.stl
# 70 trish_dmc.stl
# 71 trish_dmc.stl
# 72 trish_dmc.stl
# 73 trish_dmc.stl
# 74 trish_dmc.stl
# 75 trish_dmc.stl
# 76 trish_dmc.stl
# 77 trish_dmc.stl
# 78 trish_dmc.stl
# 79 trish_dmc.stl
# 80 trish_dmc.stl
# 81 trish_dmc.stl
# 82 trish_dmc.stl
# 83 trish_dmc.stl
# 84 trish_dmc.stl
# 85 trish_dmc.stl
# 86 trish_dmc.stl
# 87 trish_dmc.stl
# 88 trish_dmc.stl
# 89 trish_dmc.stl
# 90 trish_dmc.stl
# 91 trish_dmc.stl
# 92 trish_dmc.stl
# 93 trish_dmc.stl
# 94 trish_dmc.stl
# 95 trish_dmc.stl
# 96 trish_dmc.stl
# 97 trish_dmc.stl
# 98 trish_dmc.stl
# 99 trish_dmc.stl
# 100 trish_dmc.stl
# 31 v_dmc.stl
# 1 v_dmc.stl
# 2 v_dmc.stl
# 3 v_dmc.stl
# 4 v_dmc.stl
# 5 v_dmc.stl
# 6 v_dmc.stl
# 7 v_dmc.stl
# 8 v_dmc.stl
# 9 v_dmc.stl
# 10 v_dmc.stl
# 11 v_dmc.stl
# 12 v_dmc.stl
# 13 v_dmc.stl
# 14 v_dmc.stl
# 15 v_dmc.stl
# 16 v_dmc.stl
# 17 v_dmc.stl
# 18 v_dmc.stl
# 19 v_dmc.stl
# 20 v_dmc.stl
# 21 v_dmc.stl
# 22 v_dmc.stl
# 23 v_dmc.stl
# 24 v_dmc.stl
# 25 v_dmc.stl
# 26 v_dmc.stl
# 27 v_dmc.stl
# 28 v_dmc.stl
# 29 v_dmc.stl
# 30 v_dmc.stl
# 31 v_dmc.stl
# 32 v_dmc.stl
# 33 v_dmc.stl
# 34 v_dmc.stl
# 35 v_dmc.stl
# 36 v_dmc.stl
# 37 v_dmc.stl
# 38 v_dmc.stl
# 39 v_dmc.stl
# 40 v_dmc.stl
# 41 v_dmc.stl
# 42 v_dmc.stl
# 43 v_dmc.stl
# 44 v_dmc.stl
# 45 v_dmc.stl
# 46 v_dmc.stl
# 47 v_dmc.stl
# 48 v_dmc.stl
# 49 v_dmc.stl
# 50 v_dmc.stl
# 51 v_dmc.stl
# 52 v_dmc.stl
# 53 v_dmc.stl
# 54 v_dmc.stl
# 55 v_dmc.stl
# 56 v_dmc.stl
# 57 v_dmc.stl
# 58 v_dmc.stl
# 59 v_dmc.stl
# 60 v_dmc.stl
# 61 v_dmc.stl
# 62 v_dmc.stl
# 63 v_dmc.stl
# 64 v_dmc.stl
# 65 v_dmc.stl
# 66 v_dmc.stl
# 67 v_dmc.stl
# 68 v_dmc.stl
# 69 v_dmc.stl
# 70 v_dmc.stl
# 71 v_dmc.stl
# 72 v_dmc.stl
# 73 v_dmc.stl
# 74 v_dmc.stl
# 75 v_dmc.stl
# 76 v_dmc.stl
# 77 v_dmc.stl
# 78 v_dmc.stl
# 79 v_dmc.stl
# 80 v_dmc.stl
# 81 v_dmc.stl
# 82 v_dmc.stl
# 83 v_dmc.stl
# 84 v_dmc.stl
# 85 v_dmc.stl
# 86 v_dmc.stl
# 87 v_dmc.stl
# 88 v_dmc.stl
# 89 v_dmc.stl
# 90 v_dmc.stl
# 91 v_dmc.stl
# 92 v_dmc.stl
# 93 v_dmc.stl
# 94 v_dmc.stl
# 95 v_dmc.stl
# 96 v_dmc.stl
# 97 v_dmc.stl
# 98 v_dmc.stl
# 99 v_dmc.stl
# 100 v_dmc.stl
# 32 vergil_dmc.stl
# 1 vergil_dmc.stl
# 2 vergil_dmc.stl
# 3 vergil_dmc.stl
# 4 vergil_dmc.stl
# 5 vergil_dmc.stl
# 6 vergil_dmc.stl
# 7 vergil_dmc.stl
# 8 vergil_dmc.stl
# 9 vergil_dmc.stl
# 10 vergil_dmc.stl
# 11 vergil_dmc.stl
# 12 vergil_dmc.stl
# 13 vergil_dmc.stl
# 14 vergil_dmc.stl
# 15 vergil_dmc.stl
# 16 vergil_dmc.stl
# 17 vergil_dmc.stl
# 18 vergil_dmc.stl
# 19 vergil_dmc.stl
# 20 vergil_dmc.stl
# 21 vergil_dmc.stl
# 22 vergil_dmc.stl
# 23 vergil_dmc.stl
# 24 vergil_dmc.stl
# 25 vergil_dmc.stl
# 26 vergil_dmc.stl
# 27 vergil_dmc.stl
# 28 vergil_dmc.stl
# 29 vergil_dmc.stl
# 30 vergil_dmc.stl
# 31 vergil_dmc.stl
# 32 vergil_dmc.stl
# 33 vergil_dmc.stl
# 34 vergil_dmc.stl
# 35 vergil_dmc.stl
# 36 vergil_dmc.stl
# 37 vergil_dmc.stl
# 38 vergil_dmc.stl
# 39 vergil_dmc.stl
# 40 vergil_dmc.stl
# 41 vergil_dmc.stl
# 42 vergil_dmc.stl
# 43 vergil_dmc.stl
# 44 vergil_dmc.stl
# 45 vergil_dmc.stl
# 46 vergil_dmc.stl
# 47 vergil_dmc.stl
# 48 vergil_dmc.stl
# 49 vergil_dmc.stl
# 50 vergil_dmc.stl
# 51 vergil_dmc.stl
# 52 vergil_dmc.stl
# 53 vergil_dmc.stl
# 54 vergil_dmc.stl
# 55 vergil_dmc.stl
# 56 vergil_dmc.stl
# 57 vergil_dmc.stl
# 58 vergil_dmc.stl
# 59 vergil_dmc.stl
# 60 vergil_dmc.stl
# 61 vergil_dmc.stl
# 62 vergil_dmc.stl
# 63 vergil_dmc.stl
# 64 vergil_dmc.stl
# 65 vergil_dmc.stl
# 66 vergil_dmc.stl
# 67 vergil_dmc.stl
# 68 vergil_dmc.stl
# 69 vergil_dmc.stl
# 70 vergil_dmc.stl
# 71 vergil_dmc.stl
# 72 vergil_dmc.stl
# 73 vergil_dmc.stl
# 74 vergil_dmc.stl
# 75 vergil_dmc.stl
# 76 vergil_dmc.stl
# 77 vergil_dmc.stl
# 78 vergil_dmc.stl
# 79 vergil_dmc.stl
# 80 vergil_dmc.stl
# 81 vergil_dmc.stl
# 82 vergil_dmc.stl
# 83 vergil_dmc.stl
# 84 vergil_dmc.stl
# 85 vergil_dmc.stl
# 86 vergil_dmc.stl
# 87 vergil_dmc.stl
# 88 vergil_dmc.stl
# 89 vergil_dmc.stl
# 90 vergil_dmc.stl
# 91 vergil_dmc.stl
# 92 vergil_dmc.stl
# 93 vergil_dmc.stl
# 94 vergil_dmc.stl
# 95 vergil_dmc.stl
# 96 vergil_dmc.stl
# 97 vergil_dmc.stl
# 98 vergil_dmc.stl
# 99 vergil_dmc.stl
# 100 vergil_dmc.stl

# %%
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
from src.shared.subdivide import Subdivide

src_dir = f'./data/fitted/{512}x{512}/'

# for f in sorted(os.listdir(src_dir)):
#     src = torch.load(src_dir+f)
#     # torch.save(F.adaptive_avg_pool2d(src, 128),
#     #            f'./data/fitted/{128}x{128}/' + f)
#     # torch.save(F.adaptive_avg_pool2d(src, 256),
#     #            f'./data/fitted/{256}x{256}/' + f)
#     for sz in (16, 32, 64):
#         torch.save(F.adaptive_avg_pool2d(src, sz),
#                    f'./data/fitted/{sz}x{sz}/' + f)

# %%
subdivide = Subdivide()
subdivide.smooth(F.pad(torch.randn(1, 3, 512, 512), (1, 1, 1, 1), mode='replicate')).shape
# Out:
# torch.Size([1, 3, 512, 512])

# %%
import src.shared.util as U

for f in sorted(os.listdir(src_dir)):
    src = torch.load(src_dir+f)
    for sz in (256, 128, 64, 32, 16):
        src = F.pad(src, (1, 1, 1, 1), mode='replicate')
        src = subdivide.smooth(src)
        src = F.avg_pool2d(src, 2)
        #print(src.shape, f'./data/fitted/{sz}x{sz}/' + f)
        #U.export_stl(src[0], str(sz))
        torch.save(src, f'./data/fitted/{sz}x{sz}/' + f)

# %%
src_dir = f'./data/fitted/{512}x{512}/'

for f in sorted(os.listdir(src_dir)):
    src = torch.load(src_dir+f)
    for sz in (256, 128, 64, 32, 16):
        src = F.adaptive_avg_pool2d(src, sz)        
        torch.save(src, f'./data/fitted/{sz}x{sz}/' + f)

# %%
import torch
from perlin_cupy import (
    generate_fractal_noise_2d, generate_fractal_noise_3d,
    generate_perlin_noise_2d, generate_perlin_noise_3d
)

# %%
fractal3d = torch.zeros(30_000, 3, 32, 32)
for i in range(30_000):    
    fractal3d[i] = torch.tensor(generate_fractal_noise_3d(
        (4, 32, 32), (2, 2, 2), 2)[:3])
    if i % 100 == 0:
        print(i)
torch.save(fractal3d, 'fractal3d.pth')
